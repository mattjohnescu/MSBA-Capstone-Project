# %% [markdown]
# # Capstone Project Exploratory Data Analysis Notebook:
# **Author: Matthew Johnescu**

# %% [markdown]
# # Table of Contents:
# - [Introduction](#introduction:)
#     - [Business Problem Statement](##business-problem-statement)
#     - [Notebook Purpose](##notebook-purpose)
#     - [Notebook Imports](##notebook-imports)
#     - [Loading Data](##loading-data)
# - [Description of Data](#description-of-data)
#     - [Overview of Variables](overview-of-variables)
#     - [Glypse of Data](glypse-of-data)
#     - [Overview of Data Statistics](##overvoew-of-data-statistics)
# - [Discussion of Missing Values](#discussion-of-missing-values)
# - [Data Exploration](#data-exploration)
#     - [Descriptative Statistics for Numeric and Catigorical Values](##descriptive-statistics-for-numeric-and-catigorical-variables)
#     - [Failure Counts by PLant Location](##failure-counts-by-plant-location)
#     - [Failure Count by Package Line and Plant Location](##failure-count-by-package-line-and-plant-location)
#     - [List of Node 2 Names by Plant Location](##list-of-node-2-names-per-location)

# %% [markdown]
# # Introduction:

# %% [markdown]
# ## Busines Problem Statement:
# Swire Coca-Cola has six production plants to meet the demand of 192 million cases of various beverages from 13 different states. These plants are currently only able to meet 94.4% of the demand. One of the reasons these plants fall short of meeting the total product demand is that they are plagued with unplanned downtime. This downtime is caused by various failure modes like maintenance, mechanical failure, general wear and tear, etc.
#
# Extensive repairs result in lengthy downtimes that generate work orders in the IWC system.  The long lead times caused by these work orders cost Swire Coca-Cola $60 million annually in production losses.
#
# The purpose of this project is to create a predictive model to identify machines at risk of failure to prevent downtime and optimize Swire Coca-Cola's plant machine maintenance.

# %% [markdown]
# ## Notebook Purpose:
# The purpose of this notebook is to better understand which varibles will be the best for predicting machine downtime, visualize the structure of the data, and explain features that will be used during the modeling phase.

# %% [markdown]
# ## Notebook Imports:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Data:

# %%
# Define the path to your CSV file
file_path = r"C:/Users/johne/Downloads/IWC_Work_Orders_Extract.csv"
# file_path = r"C:/Users/matt/Downloads/IWC_Work_Orders_Extract.csv"
# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)
# Out:
# C:\Users\johne\AppData\Local\Temp\ipykernel_15624\1385790305.py:5: DtypeWarning: Columns (8,11,12,13,14,15,16,17,18,20,21,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %% [markdown]
# # Description of Data:

# %% [markdown]
# ## Overview of Variables:
#
# **Column Definitions:**
#
# - `ORDER_ID`: An identifier used to uniquely map every order raised in IWC
#
# - `PLANT_ID`: Helps uniquely identify all factories of Swire Coca-Cola, between Monza, Cota, Silverstone, Monaco, Roma, and Suzuka
#
# - `PRODUCTION_LOCATION`: Text description of `PLANT_ID`
#
# - `EXECUTION_START_DATE`: The date on which work began on the said issue
#
# - `EXECUTION_FINISH_DATE`: The date on which work ended to resolve said issue
#
# - `ACTUAL_START_TIME`: The time at which work began on resolving said issue*
#
# - `ACTUAL_FINISH_TIME`: The time at which work ended on resolving said issue*
#
# - `ACTUAL_WORK_IN_MINUTES`: The time it took, in minutes, to resolve said issue*
# - `MAINTENANCE_PLAN`: If the maintenance task was planned, this would have the plan ID. If this column is null, it implies that the maintenance was unplanned
# - `MAINTENANCE_ITEM`: If the maintenance task was planned, for example, this bearing needs to be changed every six weeks, then the plan in the IWC system will have a code allocated to it, indicating that this bearing code maintenance will repeat at X interval. The serial number in this column maps to bearings (mapping not provided for security reasons)
# - `MAINTENANCE_ACTIVITY_TYPE`: Lets you know if the maintenance was planned or unplanned, as an additional flag
# - `ORDER_DESCRIPTION`: The description entered by the mechanic regarding the actual work that was carried out in the fix
# - `MAINTENANCE_TYPE_DESCRIPTION`: Indicates if the work order was preventive in nature (i.e., done to prevent breakdowns in future) or corrective in nature (i.e., done to correct something that caused a downtime)
# - `FUNCTIONAL_LOC`: Works like an IP address. Helps locate each machine by plant – process – sub-process – product line – machine. It is broken down into nodes for better analysis
# - `FUNCTIONAL_AREA_NODE_1_MODIFIED`: The functional area within said plant – production, fleet, HVAC, etc.
# - `FUNCTIONAL_AREA_NODE_2_MODIFIED`: The region-based subset of the functional area – Is it the blender room, the assembly lines (can, bottle, or bibs)
# - `FUNCTIONAL_AREA_NODE_3_MODIFIED`: Within each region, which subset of equipment this work order belongs to
# - `FUNCTIONAL_AREA_NODE_4_MODIFIED`: Within line groupings, which line is it specifically referring to – contains line number
# - `FUNCTIONAL_AREA_NODE_5_MODIFIED`: Further splits the line into individual machine types
# - `EQUIPMENT_ID`: Helps identify which component within a larger machine (e.g., filler) the work was done on, such as a smaller component in the filler
# - `EQUIPMENT_DESC5`: Helps identify what the component is. Note that a description may not always be available due to some components being either too small to classify or proprietary
# - `EQUIPMENT_CAT_DESC`: Identifies if the fixed part was on a machine, a vehicle, an HVAC system, etc.
# - `EQUIP_START_UP_DATE`: The date on which this machine was acquired
# - `EQUIP_VALID_FROM`: The date on which this machine became functional
# - `EQUIP_VALID_TO`: The date until which this machine shall be used

# %% [markdown]
# Comment:
# - Data reflects different occurances of break downs in the Swire Coca-Cola production facilities.
# - Note that only severe breakdowns make it to having a work order issued against them. Therefore, not all breakdowns recorded on the factory floor will have IWC work orders issued against them. An analysis of location, description and package line might be a great place to get started.

# %% [markdown]
# ## Glypse of Data:

# %%
# Display the first 5 rows of the DataFrame
print("Head of the DataFrame:")
print(df.head())
# Out:
# Head of the DataFrame:
#     ORDER_ID PLANT_ID PRODUCTION_LOCATION EXECUTION_START_DATE  \
# 0  705642457     G812                ROMA           2024-05-04
# 1  704191697     G812                ROMA           2022-09-13
# 2  704466547     G812                ROMA           2022-12-21
# 3  703834477     G812                ROMA           2022-07-04
# 4  704661125     G291               MONZA           2023-03-15
#
#   EXECUTION_FINISH_DATE ACTUAL_START_TIME ACTUAL_FINISH_TIME  \
# 0            2024-05-12      06:00:00.000       23:04:08.000
# 1            2022-09-13      06:00:00.000       17:17:24.000
# 2            2022-12-21      07:00:00.000       07:00:00.000
# 3            2022-07-04      06:00:00.000       06:00:00.000
# 4            2023-03-15      07:00:00.000       07:00:00.000
#
#    ACTUAL_WORK_IN_MINUTES MAINTENANCE_PLAN  MAINTENANCE_ITEM  ...  \
# 0                   390.0              NaN               NaN  ...
# 1                   420.0              NaN               NaN  ...
# 2                    30.0              NaN               NaN  ...
# 3                    60.0              NaN               NaN  ...
# 4                   120.0              NaN               NaN  ...
#
#   FUNCTIONAL_AREA_NODE_2_MODIFIED    FUNCTIONAL_AREA_NODE_3_MODIFIED  \
# 0      G812 PRD FILLER_ROTARY_CAN  G812 PRD FILLER_ROTARY_CAN LINE 3
# 1      G812 PRD FILLER_ROTARY_CAN  G812 PRD FILLER_ROTARY_CAN LINE 3
# 2      G812 PRD FILLER_ROTARY_CAN  G812 PRD FILLER_ROTARY_CAN LINE 3
# 3      G812 PRD FILLER_ROTARY_CAN  G812 PRD FILLER_ROTARY_CAN LINE 3
# 4                     AIR SYSTEMS                                NaN
#
#   FUNCTIONAL_AREA_NODE_4_MODIFIED FUNCTIONAL_AREA_NODE_5_MODIFIED  \
# 0                        CONVEYOR               FULL CAN CONVEYOR
# 1                        CONVEYOR               FULL CAN CONVEYOR
# 2                        CONVEYOR               FULL CAN CONVEYOR
# 3                        CONVEYOR               FULL CAN CONVEYOR
# 4                             NaN                             NaN
#
#   EQUIPMENT_ID             EQUIPMENT_DESC EQUIP_CAT_DESC EQUIP_START_UP_DATE  \
# 0  300126812.0  FULL CAN CONVEYOR (FC41B)       Machines          2020-04-22
# 1  300126812.0  FULL CAN CONVEYOR (FC41B)       Machines          2020-04-22
# 2  300126812.0  FULL CAN CONVEYOR (FC41B)       Machines          2020-04-22
# 3  300126812.0  FULL CAN CONVEYOR (FC41B)       Machines          2020-04-22
# 4  300001088.0          TANK_STL_STOR_AIR       Machines          2017-02-15
#
#   EQUIP_VALID_FROM  EQUIP_VALID_TO
# 0       2020-02-10      9999-12-31
# 1       2020-02-10      9999-12-31
# 2       2020-02-10      9999-12-31
# 3       2020-02-10      9999-12-31
# 4       2023-12-11      9999-12-31
#
# [5 rows x 25 columns]

# %% [markdown]
# Comment:

# %% [markdown]
# ## Overview of Data Statistics:

# %%
# Function to show unique values and data types
def unique_values_and_data_types(df):
    # Creating a DataFrame to store unique values and data types
    unique_df = pd.DataFrame()
    unique_df['#Unique_Values'] = df.nunique()
    unique_df['Data_Type'] = df.dtypes
    unique_df['Unique_Values'] = df.apply(lambda x: x.unique())
    return unique_df

# Displaying the unique values and data types
print("Unique Values and Data Types")
print(unique_values_and_data_types(df))
# Out:
# Unique Values and Data Types
#                                  #Unique_Values Data_Type  \
# ORDER_ID                                1427244     int64
# PLANT_ID                                      6    object
# PRODUCTION_LOCATION                           6    object
# EXECUTION_START_DATE                       2956    object
# EXECUTION_FINISH_DATE                      2956    object
# ACTUAL_START_TIME                         65927    object
# ACTUAL_FINISH_TIME                        61388    object
# ACTUAL_WORK_IN_MINUTES                     4801   float64
# MAINTENANCE_PLAN                           3308    object
# MAINTENANCE_ITEM                           4021   float64
# MAINTENANCE_ACTIVITY_TYPE                     2    object
# ORDER_DESCRIPTION                        118925    object
# MAINTENANCE_TYPE_DESCRIPTION                  5    object
# FUNCTIONAL_LOC                              667    object
# FUNCTIONAL_AREA_NODE_1_MODIFIED               7    object
# FUNCTIONAL_AREA_NODE_2_MODIFIED              67    object
# FUNCTIONAL_AREA_NODE_3_MODIFIED             141    object
# FUNCTIONAL_AREA_NODE_4_MODIFIED              86    object
# FUNCTIONAL_AREA_NODE_5_MODIFIED              36    object
# EQUIPMENT_ID                               2956   float64
# EQUIPMENT_DESC                              807    object
# EQUIP_CAT_DESC                                4    object
# EQUIP_START_UP_DATE                          92    object
# EQUIP_VALID_FROM                            137    object
# EQUIP_VALID_TO                                1    object
#
#                                                                      Unique_Values
# ORDER_ID                         [705642457, 704191697, 704466547, 703834477, 7...
# PLANT_ID                                      [G812, G291, G816, G811, G221, G261]
# PRODUCTION_LOCATION               [ROMA, MONZA, COTA, MONACO, SUZUKA, SILVERSTONE]
# EXECUTION_START_DATE             [2024-05-04, 2022-09-13, 2022-12-21, 2022-07-0...
# EXECUTION_FINISH_DATE            [2024-05-12, 2022-09-13, 2022-12-21, 2022-07-0...
# ACTUAL_START_TIME                [06:00:00.000, 07:00:00.000, 08:00:00.000, 13:...
# ACTUAL_FINISH_TIME               [23:04:08.000, 17:17:24.000, 07:00:00.000, 06:...
# ACTUAL_WORK_IN_MINUTES           [390.0, 420.0, 30.0, 60.0, 120.0, 18.0, 480.0,...
# MAINTENANCE_PLAN                 [nan, G291VM1437, 000000058177, G812200714, G2...
# MAINTENANCE_ITEM                 [nan, 40534.0, 235113.0, 270277.0, 40074.0, 40...
# MAINTENANCE_ACTIVITY_TYPE                                     [Unplanned, Planned]
# ORDER_DESCRIPTION                [L2 GEARBOX LEAK (SEE ATTACHED), LINE 3 CONVEY...
# MAINTENANCE_TYPE_DESCRIPTION     [Corrective Maintenance Order, Preventive Main...
# FUNCTIONAL_LOC                   [G812-PRD-L15-L03-L030-020, G291-PRD-P05, G291...
# FUNCTIONAL_AREA_NODE_1_MODIFIED  [PRODUCTION, MONZA PRODUCTION, COTA PRODUCTION...
# FUNCTIONAL_AREA_NODE_2_MODIFIED  [G812 PRD FILLER_ROTARY_CAN, AIR SYSTEMS, AMMO...
# FUNCTIONAL_AREA_NODE_3_MODIFIED  [G812 PRD FILLER_ROTARY_CAN LINE 3, nan, PUMPS...
# FUNCTIONAL_AREA_NODE_4_MODIFIED  [CONVEYOR, nan, CODER, TANKS, PACKER, LABELER,...
# FUNCTIONAL_AREA_NODE_5_MODIFIED  [FULL CAN CONVEYOR, nan, PACK CONVEYOR, EAST S...
# EQUIPMENT_ID                     [300126812.0, 300001088.0, 300001033.0, 400027...
# EQUIPMENT_DESC                   [FULL CAN CONVEYOR (FC41B), TANK_STL_STOR_AIR,...
# EQUIP_CAT_DESC                   [Machines, Test/measurement equipment, Product...
# EQUIP_START_UP_DATE              [2020-04-22, 2017-02-15, 2022-05-01, 2023-09-0...
# EQUIP_VALID_FROM                 [2020-02-10, 2023-12-11, 2022-06-08, 2020-02-1...
# EQUIP_VALID_TO                                                   [9999-12-31, nan]

# %% [markdown]
# Comment:
# - Variables may need to be turned into str for analysis.

# %% [markdown]
# # Discussion of Missing Values:

# %%
# Function to print null values and their percentage
def null_values_percentage(df):
    total = len(df)
    # Creating a DataFrame to store null values and their percentage
    null_df = pd.DataFrame(df.isnull().sum(), columns=['#NULLS'])
    null_df['%NULLS'] = round((null_df['#NULLS'] / total) * 100, 5)
    return null_df

print("\nNull Values and Percentage")
print(null_values_percentage(df))
# Out:
# Null Values and Percentage
#                                   #NULLS    %NULLS
# ORDER_ID                               0   0.00000
# PLANT_ID                               0   0.00000
# PRODUCTION_LOCATION                    0   0.00000
# EXECUTION_START_DATE                   0   0.00000
# EXECUTION_FINISH_DATE                  0   0.00000
# ACTUAL_START_TIME                      0   0.00000
# ACTUAL_FINISH_TIME                     0   0.00000
# ACTUAL_WORK_IN_MINUTES                 0   0.00000
# MAINTENANCE_PLAN                 1274670  89.30864
# MAINTENANCE_ITEM                 1274670  89.30864
# MAINTENANCE_ACTIVITY_TYPE              0   0.00000
# ORDER_DESCRIPTION                1135497  79.55760
# MAINTENANCE_TYPE_DESCRIPTION     1135469  79.55564
# FUNCTIONAL_LOC                   1135482  79.55655
# FUNCTIONAL_AREA_NODE_1_MODIFIED  1137147  79.67321
# FUNCTIONAL_AREA_NODE_2_MODIFIED  1144857  80.21340
# FUNCTIONAL_AREA_NODE_3_MODIFIED  1168573  81.87504
# FUNCTIONAL_AREA_NODE_4_MODIFIED  1189691  83.35466
# FUNCTIONAL_AREA_NODE_5_MODIFIED  1425084  99.84726
# EQUIPMENT_ID                     1135469  79.55564
# EQUIPMENT_DESC                   1347817  94.43362
# EQUIP_CAT_DESC                   1347817  94.43362
# EQUIP_START_UP_DATE              1347817  94.43362
# EQUIP_VALID_FROM                 1347817  94.43362
# EQUIP_VALID_TO                   1347817  94.43362

# %% [markdown]
# Comment:
#
# The data includes several columns with significant amounts of missing values, which may have implications for analysis and modeling. Here is a summary of the columns with the highest percentages of missing values:
#
# 1. `MAINTENANCE_PLAN` and `MAINTENANCE_ITEM`: Both columns have approximately 89.31% missing values, which suggests that maintenance information is not frequently recorded for many entries. This could impact the predictive power of maintenance-related features.
#
# 2. `ORDER_DESCRIPTION`, `MAINTENANCE_TYPE_DESCRIPTION`, and `FUNCTIONAL_LOC`: These columns have approximately 79.56-79.67% missing values, indicating that order descriptions and maintenance type details are often omitted.
#
# 3. `FUNCTIONAL_AREA_NODE_X_MODIFIED` (where X ranges from 1 to 5): Missing values increase with the depth of the functional area nodes, with `FUNCTIONAL_AREA_NODE_5_MODIFIED` having 99.85% missing values. This pattern suggests that lower-level details are not often captured, which might reduce the granularity available for analyzing functional area details.
#
# 4. `EQUIPMENT_DESC`, `EQUIP_CAT_DESC`, `EQUIP_START_UP_DATE`, `EQUIP_VALID_FROM`, and `EQUIP_VALID_TO`: All these columns have about 94.43% missing values. This high percentage may limit the ability to analyze equipment-based trends effectively.
#
# These high levels of missing data suggests that many columns contain incomplete records, which may necessitate careful handling—either through imputation, exclusion, or deriving insights from available non-missing data points. Depending on the context, it may also make sense to consider the impact of these missing values on downstream analysis and model accuracy.

# %% [markdown]
# # Data Exploration:

# %% [markdown]
# ## Descriptive Statistics for Numeric and Catigorical Variables:

# %%
# Select numerical columns
numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Display descriptive statistics
df[numerical_cols].describe()

# Select categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# Display value counts for each categorical column
for col in categorical_cols:
    print(f'Value counts for {col}:')
    print(df[col].value_counts(dropna=False))
    print('\n')
# Out:
# Value counts for PLANT_ID:
# PLANT_ID
# G261    630903
# G221    290975
# G291    225279
# G816    116303
# G811     84694
# G812     79110
# Name: count, dtype: int64
#
#
# Value counts for PRODUCTION_LOCATION:
# PRODUCTION_LOCATION
# SILVERSTONE    630903
# SUZUKA         290975
# MONZA          225279
# COTA           116303
# MONACO          84694
# ROMA            79110
# Name: count, dtype: int64
#
#
# Value counts for EXECUTION_START_DATE:
# EXECUTION_START_DATE
# 2019-04-16    936
# 2018-09-12    908
# 2018-08-08    900
# 2023-05-23    895
# 2019-01-23    892
#              ...
# 2024-08-30      4
# 2013-08-19      1
# 2021-12-25      1
# 2016-07-25      1
# 2016-07-28      1
# Name: count, Length: 2956, dtype: int64
#
#
# Value counts for EXECUTION_FINISH_DATE:
# EXECUTION_FINISH_DATE
# 2019-04-16    934
# 2023-12-04    924
# 2018-09-12    914
# 2024-06-13    911
# 2019-01-23    902
#              ...
# 2016-07-30     12
# 2021-12-25      6
# 2016-12-25      4
# 2016-07-25      1
# 2016-07-29      1
# Name: count, Length: 2956, dtype: int64
#
#
# Value counts for ACTUAL_START_TIME:
# ACTUAL_START_TIME
# 00:00:00.000    212155
# 07:00:00.000    148181
# 06:00:00.000    139687
# 08:00:00.000     34223
# 15:30:00.000      6058
#                  ...
# 21:19:17.000         1
# 01:11:02.000         1
# 19:57:32.000         1
# 08:02:34.000         1
# 01:21:07.000         1
# Name: count, Length: 65927, dtype: int64
#
#
# Value counts for ACTUAL_FINISH_TIME:
# ACTUAL_FINISH_TIME
# 00:00:00.000    202920
# 07:00:00.000    144120
# 06:00:00.000    133447
# 08:00:00.000     33809
# 21:00:00.000      5422
#                  ...
# 04:29:36.000         1
# 05:41:13.000         1
# 21:59:07.000         1
# 22:15:10.000         1
# 16:12:37.000         1
# Name: count, Length: 61388, dtype: int64
#
#
# Value counts for MAINTENANCE_PLAN:
# MAINTENANCE_PLAN
# NaN             1274670
# 000000022943       1327
# G26111606          1311
# G812200051         1067
# G812200064         1067
#                  ...
# G291VM1078            1
# G291VM1082            1
# G812100128            1
# G812100137            1
# 000000061609          1
# Name: count, Length: 3309, dtype: int64
#
#
# Value counts for MAINTENANCE_ACTIVITY_TYPE:
# MAINTENANCE_ACTIVITY_TYPE
# Unplanned    1276877
# Planned       150387
# Name: count, dtype: int64
#
#
# Value counts for ORDER_DESCRIPTION:
# ORDER_DESCRIPTION
# NaN                                         1135497
# DTRINE                                         2012
# FILTEC, CL3 FOR LUB WHILE OPERATING            1392
# BEARING_LUBRICATION_PM                         1306
# E-STOP FOR ELEC MONTHLY SHUTDOWN               1275
#                                              ...
# ASSIST WITH REPLACING THE BELT AND TROUB          1
# REPLACED CAN SEALS ON 1, 8, 11 AND 16.            1
# BLENZER KEPT PAUSING                              1
# WORKED ON FILLER WITH CHRIS HAD TO TAKE           1
# FEED ROLLER BAD,  REPLACED                        1
# Name: count, Length: 118926, dtype: int64
#
#
# Value counts for MAINTENANCE_TYPE_DESCRIPTION:
# MAINTENANCE_TYPE_DESCRIPTION
# NaN                             1135469
# Preventive Maintenance Order     151533
# Corrective Maintenance Order     134074
# Administrative Order               6161
# Capital Order                        22
# Breakdown Maintenance Order           5
# Name: count, dtype: int64
#
#
# Value counts for FUNCTIONAL_LOC:
# FUNCTIONAL_LOC
# NaN                           1135482
# G812-PRD                         5923
# G812-PRD-A25                     4930
# G816-PRD-L15-L03-L080            4583
# G816-PRD-L15-L01-L080            4401
#                                ...
# G291-PRD-L30-L03-L180               1
# G816-FLT-F10-002                    1
# G811-PRD-L30-L03-L030-0060          1
# G816-PRD-P70-R04                    1
# G291-PRD-L15-L04-L180               1
# Name: count, Length: 668, dtype: int64
#
#
# Value counts for FUNCTIONAL_AREA_NODE_1_MODIFIED:
# FUNCTIONAL_AREA_NODE_1_MODIFIED
# NaN                       1137147
# COTA PRODUCTION             70187
# SILVERSTONE PRODUCTION      62625
# PRODUCTION                  60312
# MONZA PRODUCTION            57458
# SUZUKA PRODUCTION           36713
# COOLER SERVICE               2699
# FLEET                         123
# Name: count, dtype: int64
#
#
# Value counts for FUNCTIONAL_AREA_NODE_2_MODIFIED:
# FUNCTIONAL_AREA_NODE_2_MODIFIED
# NaN                           1144857
# CAN LINE                        34208
# BTL_PET_LINE                    32789
# LINES 1,2,9 - BOTTLE LINES      29729
# BOTTLE LINE                     27543
#                                ...
# CHEMICAL ROOM                      14
# ELECTRICAL SYSTEMS                 14
# G812 SANITATION                     3
# OZONE SYSTEMS                       1
# LIS SYSTEM                          1
# Name: count, Length: 68, dtype: int64
#
#
# Value counts for FUNCTIONAL_AREA_NODE_3_MODIFIED:
# FUNCTIONAL_AREA_NODE_3_MODIFIED
# NaN                             1168573
# LINE #4-FILLER_ROTARY_CAN         35834
# LINE #2 - FILLER_ROT_BTL_PET      23027
# LINE #1 - FILLER_ROT_BTL_PET      18290
# LINE #1-CAN_LINE                  17844
#                                  ...
# SANITATION                            1
# ELECTRICAL SYSTEMS REFRIG             1
# G811 PAINTING EXT                     1
# FLEET                                 1
# FIRST AID                             1
# Name: count, Length: 142, dtype: int64
#
#
# Value counts for FUNCTIONAL_AREA_NODE_4_MODIFIED:
# FUNCTIONAL_AREA_NODE_4_MODIFIED
# NaN                         1189691
# FILLER                        46322
# PACKER                        35230
# CONVEYOR                      34765
# LABELER                       18945
#                              ...
# BATCH STATION METER SKID          1
# MIXERS                            1
# G811 CONDENSATE RETURN            1
# CIP TANK SKID                     1
# CIP VALVE MATRIX SKID             1
# Name: count, Length: 87, dtype: int64
#
#
# Value counts for FUNCTIONAL_AREA_NODE_5_MODIFIED:
# FUNCTIONAL_AREA_NODE_5_MODIFIED
# NaN                                         1425084
# FULL CAN TO ACCUMULATION TABLE                  251
# PACKER 1, MODEL DUODOZEN 1250SX                 210
# FULL CASE CONVEYORS                             158
# EMPTY CASE CONVEYORS                            136
# FULL CASE SPIRAL TO PALLETIZER                  125
# FB CONVEYORS TO DOUGLAS/HI-CONE SPLIT           114
# COMPRESSOR                                      110
# EMPTY CAN                                       110
# PACKER 2, MODEL FENIX 185V                      108
# FULL CASE CONVEYOR                              101
# EAST SYRUP TANKS                                 98
# FULL BOTTLE CONVEYORS                            97
# EMPTY CAN CONVEYOR                               90
# *OLD SYSTEM MT CASE CONVEYORS*                   56
# LOOSE FB TO PACKER CONVEYORS                     52
# FULL CAN CONVEYOR                                50
# EVANS COOLING TUNNEL L3, INSIDE BUILDING         48
# HARTNESS TO PAI FULL CASE CONVEYORS              47
# PARTIAL CASES GPI (RIVERWOOD) TO DOUGLAS         43
# INFEED TO HICONE TO PACKER                       33
# EMPTY CAN VACUUM BLOWERS                         26
# FULL CAN INFEED GPI                              24
# DEPAL TO FILLER MT BOTTLE CONVEYORS              17
# ACCUMULATION TABLES                              16
# FULL CAN INFEED DOUGLAS/GPI (RIVERWOOD)          12
# FULL CASE GPI (RIVERWOOD)                        10
# FULL CASE FROM DOUGLAS TO PAI                     9
# FULL CASE DOUGLAS                                 7
# PACK CONVEYOR                                     6
# EVANS COOLING TUNNEL L3, OUTSIDE BUILDIN          5
# CONVEYORS FOR PALLETIZER                          4
# BLOWER SECTION #12 ACE-3-M112                     3
# FB INFEED TO DOUGLAS CONVEYORS                    1
# BLOWER SECTION #1 ACE-3-M101                      1
# BLOWER SECTION #11 ACE-3-M111                     1
# PALLET CONVEYOR                                   1
# Name: count, dtype: int64
#
#
# Value counts for EQUIPMENT_DESC:
# EQUIPMENT_DESC
# NaN                                 1347817
# L1 FILLER_ROTARY_CAN_72_VALVE          3745
# L1 FILLER_ROTARY_BTL_60_VALVE          2738
# L4 FILLER_ROTARY_CAN_100_VALVE         2511
# L2 FILLER_ROTARY_BTL_45_VALVE          2072
#                                      ...
# CASE CONVEYOR (CC2)                       1
# L10 WRAPPER_STRETCH_LANTECH_EAST          1
# FULL CAN CONVEYOR (FC45C)                 1
# CONV_RLLR_L3FCC300                        1
# INTERNAL ROLL UP DOOR                     1
# Name: count, Length: 808, dtype: int64
#
#
# Value counts for EQUIP_CAT_DESC:
# EQUIP_CAT_DESC
# NaN                           1347817
# Machines                        79224
# Production resources/tools         82
# Plant & Buildings                  77
# Test/measurement equipment         64
# Name: count, dtype: int64
#
#
# Value counts for EQUIP_START_UP_DATE:
# EQUIP_START_UP_DATE
# NaN           1347817
# 2017-02-15      53650
# 2020-04-22       4270
# 2019-10-10       4115
# 2017-06-01       3018
#                ...
# 2024-05-16          2
# 2023-09-01          2
# 1960-01-01          1
# 2019-05-01          1
# 2021-01-04          1
# Name: count, Length: 93, dtype: int64
#
#
# Value counts for EQUIP_VALID_FROM:
# EQUIP_VALID_FROM
# NaN           1347817
# 2017-02-15      32713
# 2017-02-25       6968
# 2019-10-06       4115
# 2023-12-09       2958
#                ...
# 2024-05-20          2
# 2021-09-01          1
# 2023-03-23          1
# 2021-01-26          1
# 2021-11-19          1
# Name: count, Length: 138, dtype: int64
#
#
# Value counts for EQUIP_VALID_TO:
# EQUIP_VALID_TO
# NaN           1347817
# 9999-12-31      79447
# Name: count, dtype: int64

# %%
# Filter to include only unplanned maintenance cases
df_unplanned = df[df['MAINTENANCE_ACTIVITY_TYPE'] == 'Unplanned']

# Select features to include in the analysis (including categorical)
features_to_include = [
    'ACTUAL_WORK_IN_MINUTES', 'MAINTENANCE_ITEM', 'EQUIPMENT_ID',
    'PLANT_ID', 'FUNCTIONAL_AREA_NODE_2_MODIFIED'
]

# Create a new DataFrame with the selected features
df_unplanned_subset = df_unplanned[features_to_include].dropna()

# Encode categorical variables using one-hot encoding
df_encoded = pd.get_dummies(df_unplanned_subset, columns=['PLANT_ID', 'FUNCTIONAL_AREA_NODE_2_MODIFIED'], drop_first=True)

# Create a heatmap to show correlations between all features (including encoded categorical ones)
plt.figure(figsize=(14, 10))
sns.heatmap(df_encoded.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap for Unplanned Maintenance (Including Encoded Categorical Variables)')
plt.show()

# %%
# Filter to only include unplanned maintenance cases
df_unplanned = df[df['MAINTENANCE_ACTIVITY_TYPE'] == 'Unplanned'].copy() 

# Convert 'EXECUTION_START_DATE' to datetime
df_unplanned.loc[:, 'EXECUTION_START_DATE'] = pd.to_datetime(df_unplanned['EXECUTION_START_DATE'], errors='coerce')

# Sort data by EQUIPMENT_ID and EXECUTION_START_DATE
df_unplanned = df_unplanned.sort_values(by=['EQUIPMENT_ID', 'EXECUTION_START_DATE'])

# Calculate the time difference between consecutive breakdowns for each machine
df_unplanned['TIME_BETWEEN_FAILURES'] = df_unplanned.groupby('EQUIPMENT_ID')['EXECUTION_START_DATE'].diff().dt.days

# Display the result
print(df_unplanned[['EQUIPMENT_ID', 'EXECUTION_START_DATE', 'TIME_BETWEEN_FAILURES']])
# Out:
#          EQUIPMENT_ID EXECUTION_START_DATE  TIME_BETWEEN_FAILURES
# 224341    200087110.0           2021-03-30                    NaN
# 1021363   200108112.0           2020-05-30                    NaN
# 449320    200108112.0           2020-08-04                   66.0
# 712483    200108112.0           2020-09-21                   48.0
# 844336    200108112.0           2020-12-09                   79.0
# ...               ...                  ...                    ...
# 1420536           NaN           2024-08-29                    NaN
# 167697            NaN           2024-08-30                    NaN
# 551480            NaN           2024-08-30                    NaN
# 756057            NaN           2024-08-30                    NaN
# 1308207           NaN           2024-08-30                    NaN
#
# [1276877 rows x 3 columns]

# %%
# Convert EXECUTION_START_DATE to datetime
df_unplanned['EXECUTION_START_DATE'] = pd.to_datetime(df_unplanned['EXECUTION_START_DATE'], errors='coerce')

# Remove rows with NaN values in EQUIPMENT_ID or TIME_BETWEEN_FAILURES
df_filtered = df_unplanned.dropna(subset=['EQUIPMENT_ID', 'TIME_BETWEEN_FAILURES'])

# Plotting TIME_BETWEEN_FAILURES for the filtered data
plt.figure(figsize=(10, 6))
plt.bar(df_filtered['EXECUTION_START_DATE'].astype(str), df_filtered['TIME_BETWEEN_FAILURES'], color='lightblue', edgecolor='black')
plt.title('Time Between Failures for Equipment')
plt.xlabel('Execution Start Date')
plt.ylabel('Time Between Failures (days)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Failure Counts by Plant Location:

# %%
# Ensure 'PLANT_ID' and 'PRODUCTION_LOCATION' are correctly formatted
df['PLANT_ID'] = df['PLANT_ID'].astype(str)
df['PRODUCTION_LOCATION'] = df['PRODUCTION_LOCATION'].astype(str)

# Count the number of failures per plant
location_failures = df.groupby(['PLANT_ID', 'PRODUCTION_LOCATION']).size().reset_index(name='Failure_Count')

# Sort by Failure_Count in descending order
location_failures = location_failures.sort_values(by='Failure_Count', ascending=False)

# Plotting
plt.figure(figsize=(12,6))
sns.barplot(x='PRODUCTION_LOCATION', y='Failure_Count', data=location_failures)
plt.title('Failure Counts by Plant Location')
plt.xlabel('Production Location')
plt.ylabel('Failure Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Silverstone is the biggest facility and obviously will have the majority of failures.

# %% [markdown]
# ## Failure Count by Package Line and Plant Location:

# %%
# Ensure the package line and plant columns are correctly formatted
df['FUNCTIONAL_AREA_NODE_2_MODIFIED'] = df['FUNCTIONAL_AREA_NODE_2_MODIFIED'].astype(str)
df['PRODUCTION_LOCATION'] = df['PRODUCTION_LOCATION'].astype(str)

# Filter to include only unplanned maintenance items
df_filtered = df[(df['FUNCTIONAL_AREA_NODE_2_MODIFIED'].notna()) & (df['FUNCTIONAL_AREA_NODE_2_MODIFIED'] != 'nan') & (df['MAINTENANCE_ACTIVITY_TYPE'] == 'Unplanned')]

# Count the number of failures per package line and plant
node_2_failures = df_filtered.groupby(['FUNCTIONAL_AREA_NODE_2_MODIFIED', 'PRODUCTION_LOCATION']).size().reset_index(name='Failure_Count')

# Sort by Failure_Count in descending order for better visualization
node_2_failures = node_2_failures.sort_values(by='Failure_Count', ascending=False)

# Plotting
plt.figure(figsize=(8, 11))
sns.barplot(
    x='Failure_Count',
    y='FUNCTIONAL_AREA_NODE_2_MODIFIED',
    hue='PRODUCTION_LOCATION',
    data=node_2_failures,
    dodge=False  # Stack bars of the same Package_Line together
)
plt.title('Failure Counts by Blender Room, Assembly Lines (Can, Bottle, or BIBs), and Plant Location (Unplanned Maintenance Only)')
plt.xlabel('Failure Count')
plt.ylabel('Package Line')
plt.legend(title='Plant ID')
plt.tight_layout()
plt.show()

# %% [markdown]
# Comment:
# - Are package lines different at each plant? How can this be accounted for in a predictive model?
# - This visual only shows fun area node 2, further anaysis is needed on the other functional areas.
# - It is important to understand that each plant may have different names for similar things, location may matter if the parts are the same at each location but if they are different based on location than seperation is needed.

# %% [markdown]
# ## List of Node 2 names per location:

# %%
# Ensure the relevant columns are correctly formatted
df['Package_Line'] = df['FUNCTIONAL_AREA_NODE_2_MODIFIED'].astype(str)
df['PRODUCTION_LOCATION'] = df['PRODUCTION_LOCATION'].astype(str)
df['PLANT_ID'] = df['PLANT_ID'].astype(str)

# Remove NaN values from Package_Line and Production_Location columns
df_filtered = df[df['Package_Line'].notna() & (df['Package_Line'] != 'nan') & df['PRODUCTION_LOCATION'].notna()]

# Group by Production Location (PRODUCTION_LOCATION) and extract unique package lines at each location
package_lines_by_plant = df_filtered.groupby('PRODUCTION_LOCATION')['Package_Line'].unique().reset_index()

# Convert the grouped data into a dictionary for better readability
package_lines_dict = dict(zip(package_lines_by_plant['PRODUCTION_LOCATION'], package_lines_by_plant['Package_Line']))

# Print the package lines at each production plant
for plant, package_lines in package_lines_dict.items():
    print(f"Production Plant: {plant}")
    print(f"Package Lines: {list(package_lines)}")
    print('-' * 40)
# Out:
# Production Plant: COTA
# Package Lines: ['QUALITY ASSURANCE EQUIPMENT', 'CAN LINE', 'BOTTLE LINE', 'CO2', 'SYRUP/BLENDING ROOM', 'PRODUCTION', 'RECYCLING', 'AIR SYSTEMS', 'WASTE WATER TREATMENT', 'WATER TREATMENT', 'REFRIGERATION', 'HEATING SYSTEMS', 'WAREHOUSE 1', 'NITROGEN SYSTEMS', 'SANITATION', 'FLEET FUNCTIONAL AREAS', 'CIP SYSTEMS', 'OFFICES']
# ----------------------------------------
# Production Plant: MONACO
# Package Lines: ['GROUNDS', 'LINE 1 CAN', 'LINE 2,3 PET BOTTLE LINES', 'QUALITY ASSURANCE EQUIPMENT', 'SYRUP/BLENDING  ROOM', 'PRODUCTION/FACILITIES', 'STEAM SYSTEMS', 'REFRIGERATION', 'COMMON EQUIPMENT/PRD LINES', 'RECYCLING', 'WATER TREATMENT', 'SUGAR / HFCS', 'NEW WATER TREATMENT PLANT', 'CO2', 'AIR  SYSTEMS', 'CIP SYSTEMS', 'SAFETY EQUIPMENT', 'OZONE SYSTEMS', 'SHOP / REPAIR AREA']
# ----------------------------------------
# Production Plant: MONZA
# Package Lines: ['AIR SYSTEMS', 'AMMONIA & REFRIGERATION SYSTEMS', 'ROTARY_CAN_LINE', 'BTL_PET_LINE', 'QUALITY ASSURANCE EQUIPMENT', 'SYRUP/BLENDING ROOM', 'PRODUCTION', 'SHOP / REPAIR AREA', 'LUBE CAGE', 'MOBILE EQUIPMENT', 'OFFICES', 'LOADING DOCKS', 'SAFETY EQUIPMENT', 'WATER TREATMENT', 'WAREHOUSE1', 'STEAM SYSTEMS', 'CO2 SYSTEMS', 'CHEMICAL ROOM', 'NITROGEN SYSTEMS', 'SANITATION', 'RECYCLING', 'WASTE WATER TREATMENT', 'LIS SYSTEM', 'ELECTRICAL SYSTEMS']
# ----------------------------------------
# Production Plant: ROMA
# Package Lines: ['G812 PRD FILLER_ROTARY_CAN', 'G812 AIR  SYSTEMS', 'G812 SYRUP/BLENDING  ROOM', 'G812 PRD FILLER_ROT_BTL_PET', 'G812 WASTE WATER TREATMENT', 'G812 SAFETY EQUIPMENT', 'G812 REFRIGERATION', 'G812 WATER TREATMENT', 'G812 CO2', 'G812 SHOP / REPAIR AREA', 'FLEET FUNCTIONAL AREAS', 'G812 RECYCLING', 'G812 QUALITY ASSURANCE EQUIPMENT', 'G812 STEAM SYSTEMS', 'G812 CIP SYSTEMS', 'G812 PRODUCTION', 'G812 SANITATION']
# ----------------------------------------
# Production Plant: SILVERSTONE
# Package Lines: ['LINES 3,4,10 - CAN LINES', 'LINES 1,2,9 - BOTTLE LINES', 'COMMON EQUIPMENT', 'RECYCLING', 'OFFICES', 'LINE 8      - BIB LINE', 'HEATING SYSTEMS', 'SYRUP/BLENDING ROOM', 'WASTE WATER TREATMENT', 'CO2', 'QUALITY ASSURANCE EQUIPMENT', 'NITROGEN SYSTEMS', 'WATER TREATMENT', 'REFRIGERATION', 'CIP SYSTEMS', 'SANITATION', 'AIR SYSTEMS', 'SHOP / REPAIR AREA', 'PRODUCTION', 'SAFETY EQUIPMENT', 'MOBILE EQUIPMENT']
# ----------------------------------------
# Production Plant: SUZUKA
# Package Lines: ['L4 - FILLER_ROTARY_CAN', 'L1, L2, L6 PET BOTTLE LINES', 'QUALITY ASSURANCE EQUIPMENT', 'AIR  SYSTEMS', 'WATER TREATMENT', 'SYRUP/BLENDING  ROOM', 'WASTE WATER', 'REFRIGERATION', 'NEW PM PLAN', 'COOLER SERVICE HVAC', 'CIP SYSTEMS', 'HEATING SYSTEMS', 'SANITATION', 'CO2', 'RECYCLING', 'NITROGEN SYSTEMS']
# ----------------------------------------

# %% [markdown]
# Comment:
# - Production lines are named per plant, only small over laps exist
# - May be easier to group by key word 'can', 'bottle' etc.

# %% [markdown]
# ## Balance of Unplanned and Planned Maintenance:

# %%
df = pd.DataFrame(df)

# Creating a histogram of 'MAINTENANCE_ACTIVITY_TYPE' values
plt.figure(figsize=(8, 5))
df['MAINTENANCE_ACTIVITY_TYPE'].value_counts().plot(kind='bar', color=['skyblue', 'lightgreen'])
plt.xlabel('Maintenance Activity Type')
plt.ylabel('Frequency')
plt.title('Histogram of MAINTENANCE_ACTIVITY_TYPE (Unplanned, Planned)')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Type of Maintenance Description Counts:

# %%
# Analyze MAINTENANCE_TYPE_DESCRIPTION
maintenance_type_counts = df['MAINTENANCE_TYPE_DESCRIPTION'].value_counts()

plt.figure(figsize=(10,6))
sns.barplot(x=maintenance_type_counts.values, y=maintenance_type_counts.index)
plt.title('Maintenance Type Description Counts')
plt.xlabel('Count')
plt.ylabel('Maintenance Type Description')
plt.show()

# %% [markdown]
# Comment:
# - A very large portion of Maintenance is deemed as corrective, meaning it does not relect a prevention activity and could potentially be used to better understand which actitivies are unplanned.
# - Corrective data is super important in this project, giving the team information on Preventive Maintenance is counter-productive.
# - Could the current preventative maintenance be used to help gain insight on corrective maintenance issues?

# %% [markdown]
# ## Equipment Analysis

# %%
# Count the total number of failures per EQUIPMENT_ID
equipment_failures = df['EQUIPMENT_ID'].value_counts().reset_index()
equipment_failures.columns = ['EQUIPMENT_ID', 'Failure_Count']

# Identify the top 20 equipment with the highest failure rates
top_equipment_ids = equipment_failures['EQUIPMENT_ID'].head(20)
equipment_order = top_equipment_ids.tolist()

# Filter the original data to include only these top 20 equipment IDs
df_top_equipment = df[df['EQUIPMENT_ID'].isin(top_equipment_ids)]

# Group by EQUIPMENT_ID and MAINTENANCE_ACTIVITY_TYPE, and count the number of failures
failure_counts = df_top_equipment.groupby(['EQUIPMENT_ID', 'MAINTENANCE_ACTIVITY_TYPE']).size().reset_index(name='Failure_Count')

# Ensure the EQUIPMENT_ID is ordered according to the top 20
failure_counts['EQUIPMENT_ID'] = pd.Categorical(failure_counts['EQUIPMENT_ID'], categories=equipment_order, ordered=True)

# Create the bar plot
plt.figure(figsize=(14,7))
sns.barplot(
    x='EQUIPMENT_ID',
    y='Failure_Count',
    hue='MAINTENANCE_ACTIVITY_TYPE',
    data=failure_counts,
    order=equipment_order
)
plt.title('Top 20 Equipment by Failure Count Separated by Maintenance Activity Type')
plt.xlabel('Equipment ID')
plt.ylabel('Failure Count')
plt.xticks(rotation=45)
plt.legend(title='Maintenance Activity Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# Comment:
# - Some equipment has a lot more failures than others.
# - Although preventative 'PLANNED' maintenance is in place, equipment is still having 'UNPLANNED' failures.

# %%
# Filter the data to exclude 'Planned' maintenance and exclude records where MAINTENANCE_PLAN is not NA
df_filtered = df[
    (df['MAINTENANCE_ACTIVITY_TYPE'] != 'Planned') & 
    (df['MAINTENANCE_PLAN'].isna())
]

# Count the total number of failures per EQUIPMENT_ID in the filtered data
equipment_failures = df_filtered['EQUIPMENT_ID'].value_counts().reset_index()
equipment_failures.columns = ['EQUIPMENT_ID', 'Failure_Count']

# Identify the top 20 equipment with the highest failure rates
top_equipment_ids = equipment_failures['EQUIPMENT_ID'].head(20)
equipment_order = top_equipment_ids.tolist()

# Filter the filtered data to include only these top 20 equipment IDs
df_top_equipment = df_filtered[df_filtered['EQUIPMENT_ID'].isin(top_equipment_ids)]

# Group by EQUIPMENT_ID and MAINTENANCE_TYPE_DESCRIPTION (since MAINTENANCE_ACTIVITY_TYPE is no longer 'Planned')
failure_counts = df_top_equipment.groupby(['EQUIPMENT_ID', 'MAINTENANCE_TYPE_DESCRIPTION']).size().reset_index(name='Failure_Count')

# Ensure the EQUIPMENT_ID is ordered according to the top 20
failure_counts['EQUIPMENT_ID'] = pd.Categorical(failure_counts['EQUIPMENT_ID'], categories=equipment_order, ordered=True)

# Create the bar plot
plt.figure(figsize=(14,7))
sns.barplot(
    x='EQUIPMENT_ID',
    y='Failure_Count',
    hue='MAINTENANCE_TYPE_DESCRIPTION',
    data=failure_counts,
    order=equipment_order
)
plt.title('Top 20 Equipment by Failure Count (Excluding Planned Maintenance and Non-NA MAINTENANCE_PLAN)')
plt.xlabel('Equipment ID')
plt.ylabel('Failure Count')
plt.xticks(rotation=45)
plt.legend(title='Maintenance Type Description')
plt.tight_layout()
plt.show()

# %%
# Exclude 'UNPLANNED' maintenance from the data
# Adjust the string case if necessary, depending on how 'MAINTENANCE_ACTIVITY_TYPE' is recorded in your dataset
df_unplanned = df[df['MAINTENANCE_ACTIVITY_TYPE'] != 'PLANNED']

# Total downtime per equipment (excluding 'UNPLANNED' maintenance)
equipment_downtime_total = df_unplanned.groupby('EQUIPMENT_ID')['ACTUAL_WORK_IN_MINUTES'].sum().reset_index()

# Get top 20 equipment with highest downtime
top_equipment_downtime = equipment_downtime_total.sort_values(by='ACTUAL_WORK_IN_MINUTES', ascending=False).head(20)

print(top_equipment_downtime)

# Plotting
plt.figure(figsize=(12,6))
sns.barplot(x='EQUIPMENT_ID', y='ACTUAL_WORK_IN_MINUTES', data=top_equipment_downtime)
plt.title('Top 20 Equipment by Total Downtime (Excluding Unplanned Maintenance)')
plt.xlabel('Equipment ID')
plt.ylabel('Total Downtime (Minutes)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#       EQUIPMENT_ID  ACTUAL_WORK_IN_MINUTES
# 1383   300025792.0                484506.0
# 866    300017654.0                404193.6
# 558    300009177.0                390294.6
# 867    300017655.0                376677.0
# 2152   300115000.0                331877.4
# 1296   300019388.0                312627.6
# 578    300009199.0                288931.8
# 699    300017247.0                287203.8
# 1478   300026891.0                276619.8
# 754    300017312.0                258616.8
# 1271   300019362.0                252405.0
# 376    300001505.0                238962.0
# 497    300009114.0                229947.6
# 378    300001509.0                219696.6
# 700    300017248.0                216219.0
# 755    300017313.0                209338.2
# 379    300001510.0                198628.2
# 115    300001113.0                176932.2
# 950    300017746.0                169419.6
# 495    300009112.0                149377.2

# %% [markdown]
# Comment:
# - How does time period come into play?

# %% [markdown]
# Correlation Heat Map:
